# %% [markdown]
# <a href="https://colab.research.google.com/github/Raquel901/receita-bolo-algoritmo/blob/main/Ativdade_01ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aluno:Camila Jeniffer dos Santos Vilaça
#
#
# aluna:Raquel Mota dos Santos

# %% [markdown]
# (f"10 + 5 = {10 + 5}") #Soma
#
# print(f"50 / 2 = {50 / 2}") #Divisão
#
# print(f"2 ** 3= {2 ** 3}") #Potenciação
#
# print(f"10 % 3 = {10 % 3} #Módulo
# print

# %%
print(f"10 + 5 = {10 + 5}") #Soma

print(f"50 / 2 = {50 / 2}") #Divisão

print(f"2 ** 3= {2 ** 3}") #Potenciação

print(f"10 % 3 = {10 % 3}") #Módulo
# Out:
# 10 + 5 = 15
# 50 / 2 = 25.0
# 2 ** 3= 8
# 10 % 3 = 1

# %% [markdown]
# $e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$

# %% [markdown]
# O texto pode ficar em **negrito**
#
# O texto também pode ficar em *texto em itálico*
#
# Ou mesmo com a fonte ~riscada~

# %%
s = 1
time.sleep (s)
print(time.ctime())
# Out:
# Tue Mar 17 13:58:01 2026

# %%
import time
print(time.ctime())
# Out:
# Tue Mar 17 13:06:30 2026
