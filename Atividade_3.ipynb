# %% [markdown]
# <a href="https://colab.research.google.com/github/Raquel901/receita-bolo-algoritmo/blob/main/Atividade_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculadora():
    print("--- Calculadora Python ---")
    print("Operações disponíveis:")
    print("1: Adição (+)")
    print("2: Subtração (-)")
    print("3: Multiplicação (*)")
    print("4: Divisão (/)")

    try:
        escolha = input("\nEscolha o número da operação (1/2/3/4): ")

        if escolha in ['1', '2', '3', '4']:
            num1 = float(input("Digite o primeiro número: "))
            num2 = float(input("Digite o segundo número: "))

            if escolha == '1':
                print(f"Resultado: {num1} + {num2} = {num1 + num2}")
            elif escolha == '2':
                print(f"Resultado: {num1} - {num2} = {num1 - num2}")
            elif escolha == '3':
                print(f"Resultado: {num1} * {num2} = {num1 * num2}")
            elif escolha == '4':
                if num2 != 0:
                    print(f"Resultado: {num1} / {num2} = {num1 / num2}")
                else:
                    print("Erro: Não é possível dividir por zero!")
        else:
            print("Opção inválida!")

    except ValueError:
        print("Erro: Por favor, digite apenas números.")

# Executa a calculadora
calculadora()
# Out:
# --- Calculadora Python ---
# Operações disponíveis:
# 1: Adição (+)
# 2: Subtração (-)
# 3: Multiplicação (*)
# 4: Divisão (/)
#
# Escolha o número da operação (1/2/3/4): 1
# Digite o primeiro número: 100
# Digite o segundo número: 169
# Resultado: 100.0 + 169.0 = 269.0

# %%
print(int(10 + 10))
print(int(120 - 20))
print(int(9 * 3 ))
print(int(25 / 5))
# Out:
# 20
# 100
# 27
# 5
