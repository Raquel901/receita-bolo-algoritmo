# %% [markdown]
# <a href="https://colab.research.google.com/github/Raquel901/receita-bolo-algoritmo/blob/main/RECEITA_DE_BOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade receita  de bolo/Algoritmo
#
# ALUNA: Raquel Mota dos Santos
#
# ALUNA: Camila Jeniffer dos Santos Vilaça

# %%
import time # Biblioteca para simular tempo passando

# %%
print("--- INICIANDO O ALGORITMO DO BOLO---")

--- INICIANDO O ALGORITMO DO BOLO---

# %%
# 1. Variáveis: Separando  os ingredientes  e ferramentas
temperatura_forno = 0
forma_untada = true
tigela = [] # Uma lista vazia para colocar os ingredientes
massa_homogenea = False
tempo_de_forno = 40
palito_limpo = False

# %%
# 2. Entrada/Ações Simples
